# %%
#Import libraries
import numpy as np
import scipy as sp
import pandas as pd

#Import graphing libraries and settings
import matplotlib.pyplot as plt
#%matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D


import seaborn as sns
sns.set(style="whitegrid", color_codes=True)

# %pylab inline
pylab.rcParams['figure.figsize'] = (20, 14)  #increase size of plots



#Set display options to display all data
pd.set_option('display.max_columns', 1000000)
pd.set_option('display.max_rows', 1000000)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Import csv and fill Na values 
data = pd.read_csv('Amazon.csv')
print(data.shape)
data.Summary = data.Summary.fillna('0')
data.ProfileName = data.ProfileName.fillna(' ')
# Out:
# (455000, 13)

# %%
#Create columns stating number of reviews written pre user, and per product
data['UserCounts'] = data.groupby('UserId')['UserId'].transform('count')
data['ProductCounts'] = data.groupby('ProductId')['ProductId'].transform('count')
data['Time'] = pd.to_datetime(data['Time'],unit='s')

# %%
# #removing review outliears
# data = data[data.UserCounts <= 150]
# data = data[data.UserCounts >= 2]
# #removing product outliers
# data = data[data.ProductCounts <= 550]
# data.shape

# %%
check = data[data.ProductCounts >= 550]
check.head()

single = data[data.UserCounts ==1]
len(single.ProductId.value_counts())
# Out:
# 45508

# %%
import nltk.stem
from sklearn.feature_extraction.text import CountVectorizer

# %%
english_stemmer = nltk.stem.SnowballStemmer('english')

# %%
class StemmedCountVectorizer(CountVectorizer):
    def build_analyzer(self):
        analyzer = super(StemmedCountVectorizer, self).build_analyzer()
        return lambda doc: (english_stemmer.stem(w) for w in analyzer(doc))

# %%
vectorizer = StemmedCountVectorizer(min_df=1,
stop_words='english')

# %%
X_train_text = vectorizer.fit_transform(data.Text)

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=11, max_iter=100, n_init=1000)
km.fit(X_train_text)

# %%
convert_km = pd.DataFrame(km.labels_)

# %%
results = pd.concat([data, convert_km], axis=1, ignore_index=True)
list(results.columns.values)

# %%
results.columns = ['Unnamed: 0',
 'Id',
 'ProductId',
 'UserId',
 'ProfileName',
 'HelpfulnessNumerator',
 'HelpfulnessDenominator',
 'Score',
 'Time',
 'Summary',
 'Text',
 'helpScore',
 'helpful',
 'UserCounts',
 'ProductCounts',
 'cluster']

# %%
results.cluster.value_counts()

# %%
## fix merging TODO
#clusters = pd.merge(results, data, how='left', on='ProductId')
#clusters.head()
clusters = results
# clusters.head()

# %%
cluster0 = clusters.loc[clusters['cluster'] == 0]
cluster1 = clusters.loc[clusters['cluster'] == 1]
cluster2 = clusters.loc[clusters['cluster'] == 2]
cluster3 = clusters.loc[clusters['cluster'] == 3]
cluster4 = clusters.loc[clusters['cluster'] == 4]
cluster5 = clusters.loc[clusters['cluster'] == 5]
cluster6 = clusters.loc[clusters['cluster'] == 6]
cluster7 = clusters.loc[clusters['cluster'] == 7]
cluster8 = clusters.loc[clusters['cluster'] == 8]
cluster9 = clusters.loc[clusters['cluster'] == 9]
cluster10 = clusters.loc[clusters['cluster'] == 10]
cluster11 = clusters.loc[clusters['cluster'] == 11]
cluster12 = clusters.loc[clusters['cluster'] == 12]
cluster13 = clusters.loc[clusters['cluster'] == 13]
cluster14 = clusters.loc[clusters['cluster'] == 14]
cluster15 = clusters.loc[clusters['cluster'] == 15]
cluster16 = clusters.loc[clusters['cluster'] == 16]
cluster17 = clusters.loc[clusters['cluster'] == 17]
cluster18 = clusters.loc[clusters['cluster'] == 18]
cluster19 = clusters.loc[clusters['cluster'] == 19]
cluster20 = clusters.loc[clusters['cluster'] == 20]
cluster21 = clusters.loc[clusters['cluster'] == 21]
cluster22 = clusters.loc[clusters['cluster'] == 22]
cluster23 = clusters.loc[clusters['cluster'] == 23]
cluster24 = clusters.loc[clusters['cluster'] == 24]
cluster25 = clusters.loc[clusters['cluster'] == 25]

# %%
print(cluster0.Summary.head(15))
print(cluster1.Summary.head(15))
print(cluster2.Summary.head(15))
print(cluster3.Summary.head(15))
print(cluster4.Summary.head(15))
print(cluster5.Summary.head(15))
print(cluster6.Summary.head(15))
print(cluster7.Summary.head(15))
print(cluster8.Summary.head(15))
print(cluster9.Summary.head(15))
print(cluster10.Summary.head(15))
print(cluster11.Summary.head(15))
print(cluster12.Summary.head(5))
print(cluster13.Summary.head(5))
print(cluster14.Summary.head(5))
print(cluster15.Summary.head(5))
print(cluster16.Summary.head(5))
print(cluster17.Summary.head(5))
print(cluster18.Summary.head(5))
print(cluster19.Summary.head(5))
print(cluster20.Summary.head(5))
print(cluster21.Summary.head(5))
print(cluster22.Summary.head(5))
print(cluster23.Summary.head(5))
print(cluster24.Summary.head(5))
print(cluster25.Summary.head(5))

# %%
print(cluster0.Score.value_counts())
print(cluster1.Score.value_counts())
print(cluster2.Score.value_counts())
print(cluster3.Score.value_counts())
print(cluster4.Score.value_counts())
print(cluster5.Score.value_counts())
print(cluster6.Score.value_counts())
print(cluster7.Score.value_counts())
print(cluster8.Score.value_counts())
print(cluster9.Score.value_counts())
print(cluster10.Score.value_counts())
print(cluster11.Score.value_counts())
print(cluster12.Score.value_counts())
print(cluster13.Score.value_counts())
print(cluster14.Score.value_counts())
print(cluster15.Score.value_counts())
print(cluster16.Score.value_counts())
print(cluster17.Score.value_counts())
print(cluster18.Score.value_counts())
print(cluster19.Score.value_counts())
print(cluster20.Score.value_counts())
print(cluster21.Score.value_counts())
print(cluster22.Score.value_counts())
print(cluster23.Score.value_counts())
print(cluster24.Score.value_counts())
print(cluster25.Score.value_counts())
# Out:
# 5    357
# 4    247
# 3    164
# 1     66
# 2     55
# Name: Score, dtype: int64
# 5    755
# 4    426
# 3    218
# 2    118
# 1     73
# Name: Score, dtype: int64
# 5    8123
# 4    1630
# 3     736
# 1     664
# 2     415
# Name: Score, dtype: int64
# 5    17281
# 4     2686
# 1     2487
# 3     1533
# 2     1374
# Name: Score, dtype: int64
# 5    349
# 4    121
# 3     45
# 2     24
# 1     22
# Name: Score, dtype: int64
# 5    2489
# 4     684
# 3     359
# 2     267
# 1     240
# Name: Score, dtype: int64
# 5    18
# 1    15
# 4     6
# 3     3
# Name: Score, dtype: int64
# 5    4209
# 4    1373
# 1     804
# 3     787
# 2     483
# Name: Score, dtype: int64
# 5    1424
# 4     847
# 3     440
# 1     219
# 2     204
# Name: Score, dtype: int64
# 5    1417
# 4     296
# 1     230
# 3     138
# 2     115
# Name: Score, dtype: int64
# 5    46904
# 1    11119
# 4     8962
# 3     5931
# 2     5007
# Name: Score, dtype: int64
# 5    7867
# 4    2249
# 3    1585
# 1    1134
# ...

# %%
cluster0.UserCounts.value_counts()
cluster1.UserCounts.value_counts()
cluster2.UserCounts.value_counts()
cluster3.UserCounts.value_counts()
cluster4.UserCounts.value_counts()
cluster5.UserCounts.value_counts()
cluster6.UserCounts.value_counts()
# cluster7.UserCounts.value_counts()
# cluster8.UserCounts.value_counts()
# cluster9.UserCounts.value_counts()
# cluster10.UserCounts.value_counts()
# cluster11.UserCounts.value_counts()
# cluster12.UserCounts.value_counts()
# Out:
# 29    9
# 43    5
# 6     5
# 7     4
# 3     4
# 1     4
# 81    3
# 69    2
# 2     2
# 26    1
# 24    1
# 19    1
# 5     1
# Name: UserCounts, dtype: int64

# %%
cluster0.ProductCounts.value_counts()
cluster1.ProductCounts.value_counts()
cluster2.ProductCounts.value_counts()
cluster3.ProductCounts.value_counts()
cluster4.ProductCounts.value_counts()
cluster5.ProductCounts.value_counts()
cluster6.ProductCounts.value_counts()
cluster7.ProductCounts.value_counts()
# cluster8.ProductCounts.value_counts()
# cluster9.ProductCounts.value_counts()
# cluster10.ProductCounts.value_counts()
# cluster11.ProductCounts.value_counts()
# cluster12.ProductCounts.value_counts()
# Out:
# 1      447
# 2      383
# 3      291
# 4      274
# 5      245
# 6      194
# 7      162
# 9      151
# 8      145
# 13     123
# 14     119
# 11     111
# 10     110
# 12     110
# 16      88
# 20      86
# 17      86
# 15      82
# 22      81
# 19      80
# 18      65
# 25      64
# 23      58
# 24      58
# 21      55
# 32      50
# 26      49
# 43      44
# 86      44
# 27      43
# 29      42
# 31      42
# 38      42
# 36      42
# 28      41
# 30      39
# 37      39
# 58      39
# 42      38
# 55      38
# 46      37
# 33      37
# 47      37
# 39      36
# 62      36
# 48      35
# 80      34
# 78      33
# 311     33
# 34      32
# 40      32
# 63      32
# 54      31
# 83      31
# 210     30
# 61      29
# 49      29
# 56      27
# 35      27
# 65      27
# 136     27
# 103     26
# 50      26
# 45      26
# 79      26
# 51      25
# 134     25
# 66      25
# 226     24
# 214     24
# 135     24
# 235     24
# 90      24
# 180     23
# 227     23
# 44      22
# ...

# %%
print(cluster0.Text.head(5))
print(cluster1.Text.head(5))
print(cluster2.Text.head(5))
print(cluster3.Text.head(5))
print(cluster4.Text.head(5))
print(cluster5.Text.head(5))
print(cluster6.Text.head(5))
print(cluster7.Text.head(5))
print(cluster8.Text.head(5))
print(cluster9.Text.head(5))
print(cluster10.Text.head(5))
print(cluster11.Text.head(5))
print(cluster12.Text.head(5))
print(cluster13.Text.head(5))
print(cluster14.Text.head(5))
print(cluster15.Text.head(5))
print(cluster16.Text.head(5))
print(cluster17.Text.head(5))
print(cluster18.Text.head(5))
print(cluster19.Text.head(5))
print(cluster20.Text.head(5))
print(cluster21.Text.head(5))
print(cluster22.Text.head(5))
print(cluster23.Text.head(5))
print(cluster24.Text.head(5))
print(cluster25.Text.head(5))
# Out:
# 68      I have been drinking this water for about 4 months.  I find that it absorbs into me better than ...
# 1432    I received one 1.5 liter bottle of this water from the Amazon Vine program and my husband is the...
# 2862    Until I saw & read about 9.5 pH drinking water, I didn't know that I "needed" it.  I've read the...
# 3347    I have been drinking filtered water for many years. Ever since I was young I remember growing up...
# 3714    This is marketed the same way that toothpaste is ("doctor recommended"), which for me, has the o...
# 4327    This is a good product. My husband and I both work full-time, but we also love cooking, and want...
# 5272    I drink water and tea a lot. While visiting relatives all over this planet I've imbibed water ev...
# 5650    I have lots of reasons for trying True Lemon: number one is I didn't want to drink anything with...
# 5950    I always have enjoyed the powdered water enhancers. I have no trouble meeting my daily water int...
# ...

# %%
cluster0.ProductId.value_counts()
cluster1.ProductId.value_counts()
cluster2.ProductId.value_counts()
cluster3.ProductId.value_counts()
cluster4.ProductId.value_counts()
cluster5.ProductId.value_counts()
cluster6.ProductId.value_counts()
cluster7.ProductId.value_counts()
cluster8.ProductId.value_counts()
cluster9.ProductId.value_counts()
cluster10.ProductId.value_counts()
cluster11.ProductId.value_counts()
cluster12.ProductId.value_counts()
cluster13.ProductId.value_counts()
cluster14.ProductId.value_counts()
cluster15.ProductId.value_counts()
cluster16.ProductId.value_counts()
cluster17.ProductId.value_counts()
cluster18.ProductId.value_counts()
cluster19.ProductId.value_counts()
cluster20.ProductId.value_counts()
cluster21.ProductId.value_counts()
cluster22.ProductId.value_counts()
cluster23.ProductId.value_counts()
cluster24.ProductId.value_counts()
cluster25.ProductId.value_counts()
# Out:
# B000DZFMEQ    92
# B000EVG8H4    89
# B001L4JH5I    68
# B000EDG430    44
# B000FDDESM    24
# B000FDDESC    20
# B000FDDET6    20
# B0049OQJXA    17
# B000EVWQZW    17
# B000FDDETG    14
# B000FDMLVI    13
# B000NMJWZO    13
# B000EDM772    12
# B000FDMLV8    11
# B000LKVHOW    11
# B000ED7M3Q    10
# B0028VAS8S    10
# B001FA1LF2     9
# B000FDKQCY     9
# B000KENKYE     8
# B0049YK1W0     8
# B002YLG6I8     8
# B000FDMLVS     8
# B002YLCO7K     7
# B006H34CUS     7
# B0006ZN52E     7
# B0049OPXP0     7
# B00473NTAO     7
# B001KWEZTO     7
# B003YIMENG     6
# B000FFQ1VW     6
# B0045VO4L6     5
# B002YLK9OU     5
# B0016BU82C     5
# B0049YMAII     5
# B003IWBI3U     4
# B0010OE8FI     4
# B000EDK5LM     4
# B0049YMC3Q     4
# B001ACNWUC     4
# B002YJI1BK     4
# B004UBC50S     4
# B000S4D6FE     4
# B001E5E2BS     4
# B000DZDJ0K     4
# B0045VVYWI     4
# B002JIO0RU     3
# B00176EPZ2     3
# B001DBRKNA     3
# B000LKZ7KC     3
# B000FFLXL0     3
# B004IXYLK0     3
# ...

# %%
cluster0.UserId.value_counts()
cluster1.UserId.value_counts()
cluster2.UserId.value_counts()
cluster3.UserId.value_counts()
cluster4.UserId.value_counts()
cluster5.UserId.value_counts()
cluster6.UserId.value_counts()
cluster7.UserId.value_counts()
cluster8.UserId.value_counts()
cluster9.UserId.value_counts()
cluster10.UserId.value_counts()
# cluster11.UserId.value_counts()
# cluster12.UserId.value_counts()
# cluster13.UserId.value_counts()
# cluster14.UserId.value_counts()
# cluster15.UserId.value_counts()
# cluster16.UserId.value_counts()
# cluster17.UserId.value_counts()
# cluster18.UserId.value_counts()
# cluster19.UserId.value_counts()
# cluster20.UserId.value_counts()
# cluster21.UserId.value_counts()
# cluster22.UserId.value_counts()
# cluster23.UserId.value_counts()
# cluster24.UserId.value_counts()
# cluster25.UserId.value_counts()
# Out:
# ALSAOZ1V546VT         38
# A31N6KB160O508        38
# AJB5P7GVR0MT8         33
# A4JSQFCKVKX2A         28
# A2MUGFV2TDQ47K        28
# A1FEP94TP15RG0        27
# A13K3ZLWAWN1EI        26
# A20OQMLRFNZADL        24
# A8FJHPCMKR28F         24
# A35TIC6B8MVKWG        23
# AISQLBDGS2KXR         23
# A3KIIGPRVTM1X3        23
# A38P3P5IV8T7AF        23
# ABK32ED0M15MR         22
# A2M9OWAU1VQ0VT        22
# A29NQI0OT0Q81S        22
# A1QRA8XPFUEKW5        22
# A78NS29TCGKI7         22
# A3B3F8S3RWQ4XI        22
# A16V6Y0BWZAGNI        22
# A2WNN1DQVL4LH5        22
# AEA27WV6NXOH2         22
# A38LIPX6GHLI9X        21
# A2A8KWCE8RKB9T        21
# A1ZH9LWMX5UCFJ        21
# A22CJHEXKM5Z8F        21
# AB1Q0GEDU5C0R         21
# A2RTDYMFHWP8I3        21
# A24TI0FXW07810        21
# A2TN9C5E4A0I3F        21
# A2NVPRHU3VF05G        21
# A3JGXC99P2U2RI        20
# A1ODU9IV6O87IB        20
# A3OJ5D1THAJKYY        20
# A153HSQ6QAFXDQ        20
# A1CYNZMKTXO222        20
# A21ESVL96WF620        20
# ...

# %%
print(cluster0.helpScore.value_counts())
print(cluster1.helpScore.value_counts())
print(cluster2.helpScore.value_counts())
print(cluster3.helpScore.value_counts())
print(cluster4.helpScore.value_counts())
print(cluster5.helpScore.value_counts())
print(cluster6.helpScore.value_counts())
print(cluster7.helpScore.value_counts())
print(cluster8.helpScore.value_counts())
print(cluster9.helpScore.value_counts())
print(cluster10.helpScore.value_counts())
print(cluster11.helpScore.value_counts())
print(cluster12.helpScore.value_counts())
print(cluster13.helpScore.value_counts())
print(cluster14.helpScore.value_counts())
print(cluster15.helpScore.value_counts())
print(cluster16.helpScore.value_counts())
print(cluster17.helpScore.value_counts())
print(cluster18.helpScore.value_counts())
print(cluster19.helpScore.value_counts())
print(cluster20.helpScore.value_counts())
print(cluster21.helpScore.value_counts())
print(cluster22.helpScore.value_counts())
print(cluster23.helpScore.value_counts())
print(cluster24.helpScore.value_counts())
print(cluster25.helpScore.value_counts())
# Out:
# 1.000000    165
# 0.000000     63
# 0.500000     44
# 0.666667     26
# 0.750000     12
# 0.714286     10
# 0.785714      5
# 0.400000      5
# 0.571429      5
# 0.882353      5
# 0.909091      5
# 0.600000      5
# 0.833333      4
# 0.444444      4
# 0.625000      4
# 0.333333      3
# 0.250000      3
# 0.727273      3
# 0.700000      3
# 0.800000      2
# 0.421053      2
# 0.888889      2
# 0.545455      2
# 0.681818      2
# 0.529412      2
# 0.857143      2
# 0.875000      2
# 0.950000      1
# 0.941176      1
# 0.526316      1
# 0.937500      1
# 0.718750      1
# 0.384615      1
# 0.944444      1
# 0.705882      1
# 0.818182      1
# 0.615385      1
# 0.920000      1
# 0.428571      1
# 0.153846      1
# 0.454545      1
# 0.900000      1
# 0.967742      1
# 0.650000      1
# 0.285714      1
# 0.200000      1
# 0.111111      1
# 0.480000      1
# 0.178571      1
# Name: helpScore, dtype: int64
# 1.000000    571
# 0.500000     99
# 0.000000     63
# 0.666667     44
# ...
